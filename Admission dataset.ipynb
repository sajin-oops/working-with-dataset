# %%
import pandas as pd
# df = pd.read_csv(r'D:\PPT FOR MINI PROJECT\admission 2014-2023.csv')


df = pd.read_csv(r'D:\PPT FOR MINI PROJECT\admission 2014-2023.csv', sep=';')

df
# Out:
#       Index       Education level                    Degree  \
# 0         1      Higher Education         Bachelor's degree
# 1         2      Higher Education         Bachelor's degree
# 2         3      Higher Education         Bachelor's degree
# 3         4      Higher Education         Bachelor's degree
# 4         5      Higher Education         Bachelor's degree
# ...     ...                   ...                       ...
# 5563   5564  Vocational Education  Mid-Career Professionals
# 5564   5565  Vocational Education  Mid-Career Professionals
# 5565   5566  Vocational Education  Mid-Career Professionals
# 5566   5567  Vocational Education  Mid-Career Professionals
# 5567   5568  Vocational Education  Mid-Career Professionals
#
#                     Tuition fees  ID                Branches of Science  \
# 0     Scholarship / tuition-free   1  Mathematical and Natural Sciences
# 1     Scholarship / tuition-free   1  Mathematical and Natural Sciences
# ...

# %%
df.describe()
# Out:
#              Index           ID         Year  Number of Applications  \
# count  5568.000000  5568.000000  5568.000000            5.016000e+03
# mean   2784.500000     3.913793  2018.666667            1.619659e+04
# std    1607.487481     2.588565     2.808969            4.730477e+04
# min       1.000000     1.000000  2014.000000            0.000000e+00
# 25%    1392.750000     2.000000  2016.000000            0.000000e+00
# 50%    2784.500000     2.500000  2019.000000            1.858500e+03
# 75%    4176.250000     6.000000  2021.000000            1.195125e+04
# max    5568.000000    10.000000  2023.000000            1.173461e+06
#
#        Number of Students
# count         5472.000000
# mean          3949.085161
# std          10849.685083
# min              0.000000
# 25%              0.000000
# 50%            526.500000
# 75%           2907.000000
# max         246142.000000

# %%
df.head
# Out:
# <bound method NDFrame.head of       Index       Education level                    Degree  \
# 0         1      Higher Education         Bachelor's degree
# 1         2      Higher Education         Bachelor's degree
# 2         3      Higher Education         Bachelor's degree
# 3         4      Higher Education         Bachelor's degree
# 4         5      Higher Education         Bachelor's degree
# ...     ...                   ...                       ...
# 5563   5564  Vocational Education  Mid-Career Professionals
# 5564   5565  Vocational Education  Mid-Career Professionals
# 5565   5566  Vocational Education  Mid-Career Professionals
# 5566   5567  Vocational Education  Mid-Career Professionals
# 5567   5568  Vocational Education  Mid-Career Professionals
#
#                     Tuition fees  ID                Branches of Science  \
# 0     Scholarship / tuition-free   1  Mathematical and Natural Sciences
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5568 entries, 0 to 5567
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Index                   5568 non-null   int64
#  1   Education level         5568 non-null   object
#  2   Degree                  5568 non-null   object
#  3   Tuition fees            5568 non-null   object
#  4   ID                      5568 non-null   int64
#  5   Branches of Science     5568 non-null   object
#  6   Group of Professions    5568 non-null   object
#  7   Year                    5568 non-null   int64
#  8   Number of Applications  5016 non-null   float64
#  9   Number of Students      5472 non-null   float64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 435.1+ KB

# %%
import os
os_getcwd()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 2
#       1 import os
# ----> 2 os_getcwd()
#
# NameError: name 'os_getcwd' is not defined
